# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data={
    'student_name': ['raj','ivan','durgesh','riya','harmeet','hardeep'],
    'student_id': [101,102,103,104,105,106],
    'student_marks': [10,20, 30,40, 50,60]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   student_name  student_id  student_marks
# 0          raj         101             10
# 1         ivan         102             20
# 2      durgesh         103             30
# 3         riya         104             40
# 4      harmeet         105             50
# 5      hardeep         106             60

# %%
df.head()
# Out:
#   student_name  student_id  student_marks
# 0          raj         101             10
# 1         ivan         102             20
# 2      durgesh         103             30
# 3         riya         104             40
# 4      harmeet         105             50

# %%
df.head(2)
# Out:
#   student_name  student_id  student_marks
# 0          raj         101             10
# 1         ivan         102             20

# %%
df.tail(2)
# Out:
#   student_name  student_id  student_marks
# 4      harmeet         105             50
# 5      hardeep         106             60

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   student_name  student_id  student_marks
# 0          raj         101             10
# 1         ivan         102             20
# 2      durgesh         103             30
# 3         riya         104             40
# 4      harmeet         105             50
# 5      hardeep         106             60

# %%
df.columns
# Out:
# Index(['student_name', 'student_id', 'student_marks'], dtype='object')

# %%
df.student_marks
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# Name: student_marks, dtype: int64

# %%
len(df)
# Out:
# 6

# %%
print("average marks: ",round(df.student_marks.sum()/len(df)))
# Out:
# average marks:  35
